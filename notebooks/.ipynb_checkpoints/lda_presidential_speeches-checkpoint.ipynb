# %% [markdown]
# # Topic Modeling of the American Presidential Inaugarations dataset with LDA

# %% [markdown]
# ## Set up

# %% [markdown]
# ### Install necessary packages

# %%
pip install --upgrade opendatasets numpy pandas scipy scikit-learn matplotlib seaborn gensim
# Out:
# Collecting opendatasets
#   Downloading opendatasets-0.1.22-py3-none-any.whl (15 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.9/site-packages (1.23.5)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.9/site-packages (1.5.2)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.9/site-packages (1.9.3)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.9/site-packages (1.1.3)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.9/site-packages (3.6.2)
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.9/site-packages (0.12.1)
# Requirement already satisfied: gensim in /opt/conda/lib/python3.9/site-packages (4.2.0)
# Requirement already satisfied: click in /opt/conda/lib/python3.9/site-packages (from opendatasets) (8.0.4)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.9/site-packages (from opendatasets) (4.62.3)
# Requirement already satisfied: kaggle in /opt/conda/lib/python3.9/site-packages (from opendatasets) (1.5.12)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.9/site-packages (from pandas) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/conda/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.9/site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in /opt/conda/lib/python3.9/site-packages (from scikit-learn) (1.1.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib) (3.0.7)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.9/site-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib) (1.0.6)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.9/site-packages (from matplotlib) (4.29.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: smart-open>=1.8.1 in /opt/conda/lib/python3.9/site-packages (from gensim) (6.2.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas) (1.15.0)
# Requirement already satisfied: python-slugify in /opt/conda/lib/python3.9/site-packages (from kaggle->opendatasets) (7.0.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.9/site-packages (from kaggle->opendatasets) (2.27.1)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.9/site-packages (from kaggle->opendatasets) (2021.10.8)
# Requirement already satisfied: urllib3 in /opt/conda/lib/python3.9/site-packages (from kaggle->opendatasets) (1.26.8)
# Requirement already satisfied: text-unidecode>=1.3 in /opt/conda/lib/python3.9/site-packages (from python-slugify->kaggle->opendatasets) (1.3)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests->kaggle->opendatasets) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/lib/python3.9/site-packages (from requests->kaggle->opendatasets) (2.0.12)
# Installing collected packages: opendatasets
# Successfully installed opendatasets-0.1.22
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Import packages

# %%
import os
import numpy as np
import pandas as pd
import gensim as gm
import seaborn as sns
import opendatasets as od
import regex as re
from sklearn.decomposition import LatentDirichletAllocation as LDA
from sklearn.feature_extraction.text import TfidfVectorizer
from matplotlib import pyplot as plt

# %% [markdown]
# ### Download Data
# For this step, we need the `kaggle` api which was installed above. Please follow these instructions:
# 1. Create a kaggle account
# 2. Navigate to https://kaggle.com/`username`/account -> `API` -> `Create New API Token`
# 3. Move the downloaded `kaggle.json` file to `~/.kaggle/` using a command such as `mv ~/Downloads/kaggle.json ~/.kaggle/` from the CLI or using your machine's gui`
# 4. Open the kaggle.json you should see something like `{"username":"[USERNAME]","key":"[KEY]"}`. Copy `KEY` to your clipboard
# 5. Run the command below and follow the prompts
# 6. Done! You should see `inaug_speeches.csv` in `./data` dir.

# %%
os.makedirs('../data',exist_ok=True)
od.download('https://www.kaggle.com/datasets/adhok93/presidentialaddress',data_dir='../data',force=True)
os.rename('../data/presidentialaddress/inaug_speeches.csv','../data/inaug_speeches.csv')
os.rmdir('../data/presidentialaddress')
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username:
#   aaprasad
# Your Kaggle Key:
#   ································
# Downloading presidentialaddress.zip to ../data/presidentialaddress
# 100%|██████████| 275k/275k [00:00<00:00, 10.7MB/s]

# %% [markdown]
# ### Helper Functions

# %%
def word2topic(word_topic_probs,words,n_terms=5):
    top_k_inds = np.argsort(word_topic_probs,axis=-1)[:,-1*n_terms:]
    top_k_inds = np.flip(top_k_inds,axis=-1)
    terms = {i:words[top_k_inds[i,:]].tolist() for i in range(len(word_topic_probs))}
    return terms
def topics2docs(doc_topic_probs,n_topics=3):
    top_k_inds = np.argsort(doc_topic_probs,axis=-1)[:,-1*n_topics:]
    top_k_inds = np.flip(top_k_inds,axis=-1)
    topics = {i:top_k_inds[i,:] for i in range(len(doc_topic_probs))}
    return topics

# %%
def preprocess(dataset='../data/inaug_speeches.csv'):
    speeches_df = pd.read_csv(dataset,encoding='latin1')
    speeches_df = speeches_df.drop(columns=list(speeches_df.keys())[0])
    speeches_df['Inaugural Address'] = speeches_df['Inaugural Address'].apply(lambda x: 1 if x == 'Inaugural Address' or 'first' in x else 2)
    speeches_df['text'] = speeches_df['text'].apply(lambda x: re.sub(r'<.*?>', ' ', x))
    speeches_df['text'] = speeches_df['text'].apply(lambda x: x.strip('\t')).apply(lambda x: x.strip('\n'))
    speeches_df['text'] = speeches_df['text'].apply(lambda x: x.strip('\t')).apply(lambda x: x.replace(u'\xa0',''))
    speeches = speeches_df['text'].to_list()
    tfidf = TfidfVectorizer(input='content',stop_words='english')
    X = tfidf.fit_transform(speeches)
    words = tfidf.get_feature_names_out()
    return speeches_df,X,tfidf,words
speeches_df,X,tfidf,words = preprocess()

# %%
speeches_df
# Out:
#                       Name  Inaugural Address                         Date  \
# 0        George Washington                  2     Thursday, April 30, 1789
# 1        George Washington                  2        Monday, March 4, 1793
# 2               John Adams                  1      Saturday, March 4, 1797
# 3         Thomas Jefferson                  2     Wednesday, March 4, 1801
# 4         Thomas Jefferson                  2        Monday, March 4, 1805
# 5            James Madison                  2      Saturday, March 4, 1809
# 6            James Madison                  2      Thursday, March 4, 1813
# 7             James Monroe                  2       Tuesday, March 4, 1817
# 8             James Monroe                  2        Monday, March 5, 1821
# 9        John Quincy Adams                  1        Friday, March 4, 1825
# 10          Andrew Jackson                  2     Wednesday, March 4, 1829
# 11          Andrew Jackson                  2        Monday, March 4, 1833
# 12        Martin Van Buren                  1        Monday, March 4, 1837
# 13  William Henry Harrison                  1      Thursday, March 4, 1841
# 14         James Knox Polk                  1       Tuesday, March 4, 1845
# 15          Zachary Taylor                  1        Monday, March 5, 1849
# 16         Franklin Pierce                  1        Friday, March 4, 1853
# 17          James Buchanan                  1     Wednesday, March 4, 1857
# 18         Abraham Lincoln                  2        Monday, March 4, 1861
# 19         Abraham Lincoln                  2      Saturday, March 4, 1865
# 20        Ulysses S. Grant                  2      Thursday, March 4, 1869
# 21        Ulysses S. Grant                  2       Tuesday, March 4, 1873
# 22     Rutherford B. Hayes                  1        Monday, March 5, 1877
# 23       James A. Garfield                  1        Friday, March 4, 1881
# 24        Grover Cleveland                  2     Wednesday, March 4, 1885
# 25       Benjamin Harrison                  1        Monday, March 4, 1889
# 26        Grover Cleveland                  2      Saturday, March 4, 1893
# 27        William McKinley                  2      Thursday, March 4, 1897
# 28        William McKinley                  2        Monday, March 4, 1901
# 29      Theodore Roosevelt                  1      Saturday, March 4, 1905
# 30     William Howard Taft                  1      Thursday, March 4, 1909
# 31          Woodrow Wilson                  2       Tuesday, March 4, 1913
# 32          Woodrow Wilson                  2        Monday, March 5, 1917
# 33       Warren G. Harding                  1        Friday, March 4, 1921
# 34         Calvin Coolidge                  1     Wednesday, March 4, 1925
# 35          Herbert Hoover                  1        Monday, March 4, 1929
# 36   Franklin D. Roosevelt                  2      Saturday, March 4, 1933
# 37   Franklin D. Roosevelt                  2  Wednesday, January 20, 1937
# 38   Franklin D. Roosevelt                  2     Monday, January 20, 1941
# 39   Franklin D. Roosevelt                  2   Saturday, January 20, 1945
# 40         Harry S. Truman                  1   Thursday, January 20, 1949
# 41    Dwight D. Eisenhower                  2    Tuesday, January 20, 1953
# 42    Dwight D. Eisenhower                  2     Monday, January 21, 1957
# 43         John F. Kennedy                  1     Friday, January 20, 1961
# 44   Lyndon Baines Johnson                  1  Wednesday, January 20, 1965
# 45   Richard Milhous Nixon                  2     Monday, January 20, 1969
# 46   Richard Milhous Nixon                  2   Saturday, January 20, 1973
# 47            Jimmy Carter                  1   Thursday, January 20, 1977
# 48           Ronald Reagan                  2    Tuesday, January 20, 1981
# 49           Ronald Reagan                  2     Monday, January 21, 1985
# 50             George Bush                  1     Friday, January 20, 1989
# 51            Bill Clinton                  2  Wednesday, January 21, 1993
# 52            Bill Clinton                  2             January 20, 1997
# 53          George W. Bush                  2   Saturday, January 20, 2001
# 54          George W. Bush                  2   Thursday, January 20, 2005
# 55            Barack Obama                  2    Tuesday, January 20, 2009
# 56            Barack Obama                  2     Monday, January 21, 2013
# 57         Donald J. Trump                  1     Friday, January 20, 2017
#
#                                                  text
# 0              Fellow-Citizens of the Senate and o...
# 1               Fellow Citizens:  I AM again calle...
# 2               WHEN it was first perceived, in ea...
# 3               Friends and Fellow-Citizens:  CALL...
# 4               PROCEEDING, fellow-citizens, to th...
# 5               UNWILLING to depart from examples ...
# 6               ABOUT to add the solemnity of an o...
# 7               I SHOULD be destitute of feeling i...
# 8               Fellow-Citizens:  I SHALL not atte...
# 9               IN compliance with an usage coeval...
# 10              Fellow-Citizens:  ABOUT to underta...
# 11              Fellow-Citizens:  THE will of the ...
# 12              Fellow-Citizens: The practice of a...
# 13              CALLED from a retirement which I h...
# 14              Fellow-Citizens:  WITHOUT solicita...
# 15              ELECTED by the American people to ...
# 16              My Countrymen:  IT a relief to fee...
# 17              Fellow-Citizens:  I APPEAR before ...
# 18              Fellow-Citizens of the United Stat...
# 19              Fellow-Countrymen:    AT this seco...
# 20              Citizens of the United States:  YO...
# 21              Fellow-Citizens:  UNDER Providence...
# 22              Fellow-Citizens:  WE have assemble...
# 23              Fellow-Citizens:  WE stand to-day ...
# 24              Fellow-Citizens:  IN the presence ...
# 25              Fellow-Citizens:  THERE is no cons...
# 26              My Fellow-Citizens:  IN obedience ...
# 27              Fellow-Citizens:  IN obedience to ...
# 28              My Fellow-Citizens:  WHEN we assem...
# 29              MY fellow-citizens, no people on e...
# 30              My Fellow-Citizens:  ANYONE who ha...
# 31              THERE has been a change of governm...
# 32              My Fellow Citizens:  THE four year...
# 33              My Countrymen:  WHEN one surveys t...
# 34              My Countrymen:  NO one can contemp...
# 35              My Countrymen:  THIS occasion is n...
# 36              I AM certain that my fellow Americ...
# 37              WHEN four years ago we met to inau...
# 38              ON each national day of inaugurati...
# 39              MR. Chief Justice, Mr. Vice Presid...
# 40              Mr. Vice President, Mr. Chief Just...
# 41              MY friends, before I begin the exp...
# 42              THE PRICE OF PEACE Mr. Chairman, M...
# 43              Vice President Johnson, Mr. Speake...
# 44              My fellow countrymen, on this occa...
# 45              Senator Dirksen, Mr. Chief Justice...
# 46              Mr. Vice President, Mr. Speaker, M...
# 47              FOR myself and for our Nation, I w...
# 48              Senator Hatfield, Mr. Chief Justic...
# 49              Senator Mathias, Chief Justice Bur...
# 50              Mr. Chief Justice, Mr. President, ...
# 51              My fellow citizens:Today we celebr...
# 52              My fellow citizens:At this last pr...
# 53              President Clinton, distinguished g...
# 54              Vice President Cheney, Mr. Chief J...
# 55              My fellow citizens:    I stand her...
# 56              Vice President Biden, Mr. Chief Ju...
# 57             Chief Justice Roberts, President Ca...

# %%
N_TOPICS = 20
lda = LDA(n_components=N_TOPICS)
logits = lda.fit_transform(X)
cluster_labels = np.argmax(logits,axis=1)
lda.components_.shape
# Out:
# (20, 8864)

# %%
N_TERMS = 5
topic_words = word2topic(lda.components_,words,n_terms=N_TERMS)
print(f'Top {N_TERMS} words occuring in each of the {N_TOPICS} topics')
for topic,terms in topic_words.items():
    print(f'Topic {topic}: {terms}')
# Out:
# Top 5 words occuring in each of the 20 topics
# Topic 0: ['occasionally', 'designed', 'slightest', 'evidently', 'unequaled']
# Topic 1: ['dollar', 'micah', 'paying', 'deal', 'pleasing']
# Topic 2: ['amendment', 'interstate', 'familiar', 'stirred', 'studied']
# Topic 3: ['decline', 'charter', 'intellectual', 'necessarily', 'strongly']
# Topic 4: ['measures', 'sense', 'course', 'look', 'resources']
# Topic 5: ['learned', 'regards', 'trend', 'mistakes', 'aright']
# Topic 6: ['represents', 'array', 'definite', 'polls', 'experiences']
# Topic 7: ['strives', 'rhetoric', 'moon', 'skills', 'angry']
# Topic 8: ['decline', 'charter', 'intellectual', 'necessarily', 'strongly']
# Topic 9: ['stricken', 'inculcate', 'proportion', 'roman', 'necessarily']
# Topic 10: ['don', 'breeze', 'door', 'word', 'blowing']
# Topic 11: ['belligerent', 'paternalism', 'degradation', 'entitle', 'discouragement']
# Topic 12: ['world', 'america', 'new', 'freedom', 'let']
# Topic 13: ['wished', 'currents', 'drawn', 'singular', 'outside']
# Topic 14: ['government', 'people', 'shall', 'states', 'country']
# Topic 15: ['sides', 'woe', 'offenses', 'answered', 'dare']
# Topic 16: ['covenant', 'willingly', 'arrive', 'upbraidings', 'violated']
# Topic 17: ['decline', 'charter', 'intellectual', 'necessarily', 'strongly']
# Topic 18: ['immutable', 'providential', 'pecuniary', 'impressions', 'article']
# Topic 19: ['civility', 'story', 'recovery', 'philosophy', 'major']

# %%
N_TOPICS_PER_DOC=5
print(f'Top {N_TOPICS_PER_DOC} topics appearing in each of the {X.shape[0]} documents')
topic_docs = topics2docs(logits,N_TOPICS_PER_DOC)
for doc,topics in topic_docs.items():
    topics = ', '.join([str(topic) for topic in topics])
    name = speeches_df.iloc[doc]['Name']
    ia = speeches_df.iloc[doc]['Inaugural Address']
    print(f'{name}\'s Inaugural Address #{ia}: {topics}')
# Out:
# Top 5 topics appearing in each of the 58 documents
# George Washington's Inaugural Address #2: 14, 18, 4, 12, 2
# George Washington's Inaugural Address #2: 14, 16, 4, 12, 15
# John Adams's Inaugural Address #1: 14, 1, 4, 12, 11
# Thomas Jefferson's Inaugural Address #2: 4, 14, 12, 15, 17
# Thomas Jefferson's Inaugural Address #2: 14, 15, 4, 12, 2
# James Madison's Inaugural Address #2: 14, 11, 4, 12, 2
# James Madison's Inaugural Address #2: 4, 14, 12, 18, 15
# James Monroe's Inaugural Address #2: 14, 4, 12, 15, 9
# James Monroe's Inaugural Address #2: 14, 10, 4, 12, 16
# John Quincy Adams's Inaugural Address #1: 14, 4, 12, 16, 10
# Andrew Jackson's Inaugural Address #2: 4, 14, 12, 17, 3
# Andrew Jackson's Inaugural Address #2: 14, 9, 4, 12, 2
# Martin Van Buren's Inaugural Address #1: 14, 0, 4, 12, 5
# William Henry Harrison's Inaugural Address #1: 14, 9, 4, 12, 2
# James Knox Polk's Inaugural Address #1: 14, 4, 12, 16, 2
# Zachary Taylor's Inaugural Address #1: 14, 4, 2, 12, 13
# Franklin Pierce's Inaugural Address #1: 14, 12, 4, 10, 15
# James Buchanan's Inaugural Address #1: 14, 18, 4, 12, 15
# Abraham Lincoln's Inaugural Address #2: 14, 4, 12, 2, 19
# Abraham Lincoln's Inaugural Address #2: 14, 15, 12, 4, 2
# Ulysses S. Grant's Inaugural Address #2: 14, 1, 12, 4, 2
# Ulysses S. Grant's Inaugural Address #2: 14, 12, 4, 17, 3
# Rutherford B. Hayes's Inaugural Address #1: 14, 13, 4, 12, 2
# James A. Garfield's Inaugural Address #1: 14, 12, 4, 15, 2
# Grover Cleveland's Inaugural Address #2: 14, 4, 12, 17, 3
# Benjamin Harrison's Inaugural Address #1: 14, 16, 12, 4, 15
# Grover Cleveland's Inaugural Address #2: 14, 12, 4, 11, 2
# William McKinley's Inaugural Address #2: 14, 12, 4, 2, 9
# William McKinley's Inaugural Address #2: 12, 14, 4, 2, 15
# Theodore Roosevelt's Inaugural Address #1: 14, 12, 5, 4, 15
# William Howard Taft's Inaugural Address #1: 14, 2, 12, 4, 16
# Woodrow Wilson's Inaugural Address #2: 14, 2, 12, 4, 16
# Woodrow Wilson's Inaugural Address #2: 14, 12, 13, 4, 19
# Warren G. Harding's Inaugural Address #1: 14, 12, 4, 5, 1
# Calvin Coolidge's Inaugural Address #1: 14, 6, 12, 4, 15
# Herbert Hoover's Inaugural Address #1: 14, 12, 4, 2, 1
# Franklin D. Roosevelt's Inaugural Address #2: 14, 9, 12, 4, 15
# Franklin D. Roosevelt's Inaugural Address #2: 14, 12, 4, 16, 7
# Franklin D. Roosevelt's Inaugural Address #2: 4, 14, 12, 15, 10
# Franklin D. Roosevelt's Inaugural Address #2: 14, 12, 5, 4, 15
# Harry S. Truman's Inaugural Address #1: 14, 12, 19, 4, 2
# Dwight D. Eisenhower's Inaugural Address #2: 12, 14, 4, 15, 2
# Dwight D. Eisenhower's Inaugural Address #2: 14, 12, 7, 4, 16
# John F. Kennedy's Inaugural Address #1: 12, 14, 15, 4, 19
# Lyndon Baines Johnson's Inaugural Address #1: 16, 12, 14, 4, 5
# Richard Milhous Nixon's Inaugural Address #2: 12, 14, 7, 4, 16
# Richard Milhous Nixon's Inaugural Address #2: 12, 14, 11, 4, 19
# Jimmy Carter's Inaugural Address #1: 14, 12, 1, 4, 5
# Ronald Reagan's Inaugural Address #2: 12, 14, 16, 4, 5
# Ronald Reagan's Inaugural Address #2: 12, 14, 4, 1, 7
# George Bush's Inaugural Address #1: 12, 14, 10, 4, 5
# Bill Clinton's Inaugural Address #2: 12, 14, 4, 17, 3
# Bill Clinton's Inaugural Address #2: 12, 14, 19, 4, 16
# George W. Bush's Inaugural Address #2: 12, 14, 19, 4, 2
# George W. Bush's Inaugural Address #2: 12, 14, 4, 15, 19
# Barack Obama's Inaugural Address #2: 12, 14, 13, 4, 15
# Barack Obama's Inaugural Address #2: 12, 14, 2, 4, 5
# Donald J. Trump's Inaugural Address #1: 12, 14, 4, 10, 17
